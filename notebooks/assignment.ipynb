# %% [markdown]
# # Assignment
#
# ## Brief
#
# Write the Python codes for the following questions.

# %% [markdown]
# ## Instructions
#
# Paste the answer as Python in the answer code section below each question.

# %% [markdown]
# ## Import Required Libraries
#
# Import matplotlib, numpy, and seaborn as needed for the following questions.

# %%
# %matplotlib qt
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Question 1
#
# Question: How do you create a 2x2 subplot grid in matplotlib and select the first subplot?

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)

# %% [markdown]
# ### Question 2
#
# Question: How to plot a line and set the color to red and style to dash in a matplotlib plot?
#
# x = [1, 2, 3, 4]
# y = [1, 4, 9, 16]

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

fig = plt.figure()
plt.plot(x,y,'--r')

# %% [markdown]
# ### Question 3
#
# Question: How to plot a histogram with 30 bins for `data` in matplotlib?
#
# data = np.random.randn(1000)

# %%
data = np.random.randn(1000)

fig = plt.figure()
plt.hist(data, bins=30)
# Out:
# (array([ 1.,  0.,  2.,  1.,  2.,  7.,  7., 21., 30., 30., 44., 44., 73.,
#         73., 94., 95., 85., 88., 70., 67., 39., 47., 23., 20., 12., 10.,
#          7.,  4.,  3.,  1.]),
#  array([-3.58893761, -3.36189121, -3.13484482, -2.90779843, -2.68075204,
#         -2.45370565, -2.22665925, -1.99961286, -1.77256647, -1.54552008,
#         -1.31847369, -1.09142729, -0.8643809 , -0.63733451, -0.41028812,
#         -0.18324173,  0.04380467,  0.27085106,  0.49789745,  0.72494384,
#          0.95199023,  1.17903663,  1.40608302,  1.63312941,  1.8601758 ,
#          2.08722219,  2.31426859,  2.54131498,  2.76836137,  2.99540776,
#          3.22245415]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Question 4
#
# Question: How can you set the x-axis and y-axis labels in a matplotlib plot?

# %%
fig = plt.figure()
plt.plot([1, 2, 3], [4, 5, 6])
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# ### Question 5
#
# Question: How do you create a bar plot in seaborn using the `tips` dataset to show the average tip amount per day?
#
# import seaborn as sns
# tips = sns.load_dataset('tips')

# %%
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="tip", data=tips, errorbar=None)
ax.set_title("Average Tips by Day")
ax.set_xlabel("Day of the Week")
ax.set_ylabel("Average Tip ($)")
ax.set_ylim(2.5,3.5)
plt.show()

# %% [markdown]
# ### Question 6
#
# Question: How to create a box plot for total_bill categorized by day in the `tips` dataset using seaborn?

# %%
fig = plt.figure()
ax = sns.boxplot(x="day", y="total_bill", data=tips)
ax.set_title("Total Bill Distribution by Day")
ax.set_xlabel("Day of the Week")
ax.set_ylabel("Total Bill ($)")
plt.show()

# %% [markdown]
# ## Submission
#
# - Submit the URL of the GitHub Repository that contains your work to NTU black board.
# - Should you reference the work of your classmate(s) or online resources, give them credit by adding either the name of your classmate or URL.
